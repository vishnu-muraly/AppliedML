# %%
import matplotlib.pyplot as plt
import ruptures as rpt

# %%
n_samples,dim,sigma=1000,1,4
#n_bkps=2
signal, bkps = rpt.pw_constant(n_samples, dim,  noise_std=sigma)

# %%
pw_constant(n_samples, dim,  noise_std=sigma)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-d4954fc00496> in <module>
# ----> 1 pw_constant(n_samples, dim,  noise_std=sigma)
#
# NameError: name 'pw_constant' is not defined

# %%
algo = rpt.Pelt(model="rbf").fit(signal)
result = algo.predict(pen=10)

# %%
rpt.display(signal, bkps,result)
plt.show()

# %%
import pandas as pd

# %%
df=pd.DataFrame(signal)
df.columns=['value']
df.head()
